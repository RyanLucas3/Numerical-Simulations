# %%
import numpy as np
from System_A_main import *

# %%
### Simulation Specifications ###
T_1 = np.arange(1, 31)
C_1 = [1, 2, 0.1]
T_2 = np.arange(31, 64)
C_2 = [10, 0.2, -0.5]
W = [20, 40]
P = [1,2,3]
k = 3
N = np.arange(1,3)
learning_function = [10, 2, 0.95, '(AR2, w20)']

# %%
output = system_A(T_1, C_1, T_2, C_2, W, P, k, N, learning_function, csv_directory="")
# Out:
#   0%|          | 0/2 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b24b6e814972> in <module>
# ----> 1 output = system_A(T_1, C_1, T_2, C_2, W, P, k, N, learning_function, csv_directory="")
#
# ~/Desktop/OPRG1/Codes/RSS_Code/Section_3/3.2/3.2.1_SysA/SystemA1/System_A1.py in system_A(T_1, C_1, T_2, C_2, W, P, k, N, learning_function, csv_directory)
#     314             for criterion in ['bic', 'aic']:
#     315
# --> 316                 model = auto_arima(y=simulated_data[(
#     317                     t - w + 1): (t + 1)], max_p=3, start_d=0, max_d=1,  max_q=1, start_q=0, information_criterion=criterion)
#     318
#
# ...
